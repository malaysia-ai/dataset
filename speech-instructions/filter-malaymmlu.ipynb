# %%
# !wget https://raw.githubusercontent.com/UMxYTL-AI-Labs/MalayMMLU/refs/heads/main/data/MalayMMLU_0shot.json

# %%
import re
import json

# %%
with open('MalayMMLU_0shot.json') as fopen:
    d = json.load(fopen)

rejected = ['II', '#', '<', '+', '~', '*']

ABCDE = 'ABCDE'
sound = {
    'A': 'Aee',
    'B': 'Bee',
    'C': 'See',
    'D': 'Dee',
    'E': 'Eee',
}

filtered = []
original = []
for d_ in d:
    if len(re.findall(r'\b\d+\b', d_['prompt'])):
        continue
    
    if any([r in d_['prompt'] for r in rejected]):
        continue
    
    t = d_['prompt'].replace('\n', ' ')
    
    for k, v in sound.items():
        t = t.replace(f'{k}.', f'. {v} . ')
        
    t = re.sub(r'\.{3,}', ', Tempat Kosong , ', t)
    t = re.sub(r'_{3,}', ', Tempat Kosong , ', t)
    
    t = re.sub(r'[ ]+', ' ', t).strip()
    
    filtered.append({
        'question': d_['prompt'],
        'pronunciation': t,
        'answer': d_['answer']
    })
    original.append(d_)
    
len(filtered)
# Out:
# 20437

# %%
with open('filter-dialects.json') as fopen:
    speakers = json.load(fopen)

# %%
import random

s = random.sample(speakers, k = len(filtered))
for i in range(len(s)):
    t = re.sub(r"<\|.*?\|>", "", s[i]['new_text']).strip()
    s[i]['transcription'] = t
    s[i].pop('new_text', None)
    s[i]['audio'] = s[i].pop('audio_filename')

for i in range(len(filtered)):
    filtered[i]['speaker'] = s[i]
    
with open('malaymmlu.json', 'w') as fopen:
    json.dump(filtered, fopen)
    
with open('filtered-malaymmlu.json', 'w') as fopen:
    json.dump(original, fopen)

# %%
filtered[-4]
# Out:
# {'question': 'Analisis IPO adalah untuk menganalpasti data input, proses untuk mengubah nilai data kepada maklumat dan paparan OUTPUT maklumat stelah proses\nA. Benar\nB. Salah',
#  'pronunciation': 'Analisis IPO adalah untuk menganalpasti data input, proses untuk mengubah nilai data kepada maklumat dan paparan OUTPUT maklumat stelah proses . Aee . Benar . Bee . Salah',
#  'answer': 'A. Benar',
#  'speaker': {'transcription': 'Haa, hebat mana pun, dialek bukanlah bahasa. Jadi, kawan saya, Profesor James Collin, dia memang pakar dalam dialektologi ini. Dan telah muraikan dengan jelas dalam buku-buku tulisan beliau. Jadi, banyak buku tulisan beliau yang diterbitkan oleh Dewan Bahasa mengenai bahasa Melayu dan dialek-dialek. Itu yang pertama sekali. Jadi, bila kita berbincang di peringkat umum, kita lupakan dialek ini. Saya pernah dulu menganjurkan latihan bahasa Melayu',
#   'audio': '/home/husein/ssd3/dialects_processed/Sembang Tamu： Bahasa Melayu di Persada Dunia： Siri 5 [PcOv1wMN6bg]/Sembang Tamu： Bahasa Melayu di Persada Dunia： Siri 5 [PcOv1wMN6bg]_175.mp3'}}

# %%
filtered[5109]
# Out:
# {'question': 'Ketika ini Arkib Negara Malaysia sedang bekerjasama dengan arkib di United Kingdom dengan membuat salinan supaya penyelidik tidak perlu ke luar negara untuk  _____  dokumen itu\nA. meneliti\nB. penelitian\nC. diteliti',
#  'pronunciation': 'Ketika ini Arkib Negara Malaysia sedang bekerjasama dengan arkib di United Kingdom dengan membuat salinan supaya penyelidik tidak perlu ke luar negara untuk , Tempat Kosong , dokumen itu . Aee . meneliti . Bee . penelitian . See . diteliti',
#  'answer': 'A. meneliti',
#  'speaker': {'transcription': 'Kita, saya sediakan, uh, irama, ano, uh, saya sediakan teks syaira separahu.',
#   'audio': '/home/husein/ssd3/dialects_processed/Rancangan Yang Lama Dijunjung： Syair： Tak Lapuk Dek Hujan Tak Lekang Dek Panas [UQmxn9au2Xw]/Rancangan Yang Lama Dijunjung： Syair： Tak Lapuk Dek Hujan Tak Lekang Dek Panas [UQmxn9au2Xw]_127.mp3'}}
